# %%
# Step 0: Install Required Tools and Libraries
# Update package list
# !apt-get update

# Install build tools and SRA Toolkit
# !apt-get install -y build-essential sra-toolkit unzip

# Download and compile STAR
# !wget https://github.com/alexdobin/STAR/archive/2.7.10a.zip
# !unzip 2.7.10a.zip
# !cd STAR-2.7.10a/source && make STAR
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,437 kB]
# Get:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,526 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,826 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.5 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,856 kB]
# Fetched 20.1 MB in 2s (10.0 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# unzip is already the newest version (6.0-26ubuntu3.2).
# The following additional packages will be installed:
#   blends-common libkdf5-2 libncbi-vdb2 libncbi-wvdb2 med-config menu
# Suggested packages:
#   blends-doc menu-l10n gksu | kde-runtime | ktsuss
# The following NEW packages will be installed:
#   blends-common libkdf5-2 libncbi-vdb2 libncbi-wvdb2 med-config menu
#   sra-toolkit
# 0 upgraded, 7 newly installed, 0 to remove and 4 not upgraded.
# Need to get 8,290 kB of archives.
# After this operation, 23.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 menu amd64 2.1.47ubuntu4 [354 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 blends-common all 0.7.4ubuntu1 [15.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libkdf5-2 amd64 2.11.2+dfsg-4build2 [14.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libncbi-vdb2 amd64 2.11.2+dfsg-4build2 [1,364 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libncbi-wvdb2 amd64 2.11.2+dfsg-4build2 [1,252 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 sra-toolkit amd64 2.11.3+dfsg-1ubuntu1 [5,277 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 med-config all 3.7.1 [11.6 kB]
# Fetched 8,290 kB in 2s (4,210 kB/s)
# Preconfiguring packages ...
# Selecting previously unselected package menu.
# (Reading database ... 117072 files and directories currently installed.)
# Preparing to unpack .../0-menu_2.1.47ubuntu4_amd64.deb ...
# Unpacking menu (2.1.47ubuntu4) ...
# Selecting previously unselected package blends-common.
# Preparing to unpack .../1-blends-common_0.7.4ubuntu1_all.deb ...
# Unpacking blends-common (0.7.4ubuntu1) ...
# Selecting previously unselected package libkdf5-2.
# Preparing to unpack .../2-libkdf5-2_2.11.2+dfsg-4build2_amd64.deb ...
# Unpacking libkdf5-2 (2.11.2+dfsg-4build2) ...
# Selecting previously unselected package libncbi-vdb2.
# Preparing to unpack .../3-libncbi-vdb2_2.11.2+dfsg-4build2_amd64.deb ...
# Unpacking libncbi-vdb2 (2.11.2+dfsg-4build2) ...
# Selecting previously unselected package libncbi-wvdb2.
# Preparing to unpack .../4-libncbi-wvdb2_2.11.2+dfsg-4build2_amd64.deb ...
# Unpacking libncbi-wvdb2 (2.11.2+dfsg-4build2) ...
# Selecting previously unselected package sra-toolkit.
# Preparing to unpack .../5-sra-toolkit_2.11.3+dfsg-1ubuntu1_amd64.deb ...
# Unpacking sra-toolkit (2.11.3+dfsg-1ubuntu1) ...
# Selecting previously unselected package med-config.
# Preparing to unpack .../6-med-config_3.7.1_all.deb ...
# Unpacking med-config (3.7.1) ...
# Setting up libncbi-vdb2 (2.11.2+dfsg-4build2) ...
# Setting up libkdf5-2 (2.11.2+dfsg-4build2) ...
# Setting up libncbi-wvdb2 (2.11.2+dfsg-4build2) ...
# Setting up menu (2.1.47ubuntu4) ...
# Setting up blends-common (0.7.4ubuntu1) ...
# Setting up sra-toolkit (2.11.3+dfsg-1ubuntu1) ...
# Setting up med-config (3.7.1) ...
# Adding group `med' (GID 107) ...
# Done.
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.11) ...
# Processing triggers for menu (2.1.47ubuntu4) ...
# --2025-11-11 05:09:28--  https://github.com/alexdobin/STAR/archive/2.7.10a.zip
# Resolving github.com (github.com)... 140.82.116.3
# Connecting to github.com (github.com)|140.82.116.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/alexdobin/STAR/zip/refs/tags/2.7.10a [following]
# --2025-11-11 05:09:28--  https://codeload.github.com/alexdobin/STAR/zip/refs/tags/2.7.10a
# Resolving codeload.github.com (codeload.github.com)... 140.82.116.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.116.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘2.7.10a.zip’
#
# 2.7.10a.zip             [      <=>           ]  11.86M  6.48MB/s    in 1.8s
#
# 2025-11-11 05:09:30 (6.48 MB/s) - ‘2.7.10a.zip’ saved [12437043]
#
# Archive:  2.7.10a.zip
# 7f0f3f16ebf232963e99891b5d3fecba071bdd57
#    creating: STAR-2.7.10a/
#   inflating: STAR-2.7.10a/.gitignore
#  extracting: STAR-2.7.10a/.gitmodules
#   inflating: STAR-2.7.10a/.travis.yml
#   inflating: STAR-2.7.10a/CHANGES.md
#   inflating: STAR-2.7.10a/CODE_OF_CONDUCT.md
#   inflating: STAR-2.7.10a/CONTRIBUTING.md
#   inflating: STAR-2.7.10a/LICENSE
#   inflating: STAR-2.7.10a/README.md
#   inflating: STAR-2.7.10a/RELEASEnotes.md
#   inflating: STAR-2.7.10a/_config.yml
#    creating: STAR-2.7.10a/bin/
#    creating: STAR-2.7.10a/bin/Linux_x86_64/
#   inflating: STAR-2.7.10a/bin/Linux_x86_64/STAR
#   inflating: STAR-2.7.10a/bin/Linux_x86_64/STARlong
#    creating: STAR-2.7.10a/bin/Linux_x86_64_static/
#   inflating: STAR-2.7.10a/bin/Linux_x86_64_static/STAR
#   inflating: STAR-2.7.10a/bin/Linux_x86_64_static/STARlong
#    creating: STAR-2.7.10a/bin/MacOSX_x86_64/
#   inflating: STAR-2.7.10a/bin/MacOSX_x86_64/STAR
#   inflating: STAR-2.7.10a/bin/MacOSX_x86_64/STARlong
#    creating: STAR-2.7.10a/doc/
#   inflating: STAR-2.7.10a/doc/STARmanual.pdf
#    creating: STAR-2.7.10a/docs/
#   inflating: STAR-2.7.10a/docs/STARconsensus.md
#   inflating: STAR-2.7.10a/docs/STARsolo.md
#    creating: STAR-2.7.10a/extras/
#    creating: STAR-2.7.10a/extras/doc-latex/
#   inflating: STAR-2.7.10a/extras/doc-latex/STARmanual.tex
#   inflating: STAR-2.7.10a/extras/doc-latex/convertParDefToLatexTable.awk
#   inflating: STAR-2.7.10a/extras/doc-latex/parametersDefault.tex
#    creating: STAR-2.7.10a/extras/docker/
#   inflating: STAR-2.7.10a/extras/docker/Dockerfile
#    creating: STAR-2.7.10a/extras/parameters/
#   inflating: STAR-2.7.10a/extras/parameters/ENCODE.txt
#    creating: STAR-2.7.10a/extras/scripts/
#   inflating: STAR-2.7.10a/extras/scripts/calcInsertCoverage.awk
#   inflating: STAR-2.7.10a/extras/scripts/extractSJfromGTF.sh
#   inflating: STAR-2.7.10a/extras/scripts/filterCirc.awk
#   inflating: STAR-2.7.10a/extras/scripts/mergeGeneCounts.awk
#   inflating: STAR-2.7.10a/extras/scripts/mergeLogFinal.awk
#   inflating: STAR-2.7.10a/extras/scripts/mergeSuperContig.awk
#   inflating: STAR-2.7.10a/extras/scripts/sjBED12.awk
#   inflating: STAR-2.7.10a/extras/scripts/sjCollapseSamples.awk
#   inflating: STAR-2.7.10a/extras/scripts/sjFromSAMcollapseUandM.awk
#   inflating: STAR-2.7.10a/extras/scripts/sjFromSAMcollapseUandM_inclOverlaps.awk
#   inflating: STAR-2.7.10a/extras/scripts/sjMotif.m
#   inflating: STAR-2.7.10a/extras/scripts/soloBasicCellFilter.awk
#   inflating: STAR-2.7.10a/extras/scripts/soloCompareMtx.awk
#   inflating: STAR-2.7.10a/extras/scripts/soloCountMatrixFromBAM.awk
#   inflating: STAR-2.7.10a/extras/scripts/soloExtractFiltCells.awk
#   inflating: STAR-2.7.10a/extras/scripts/soloUMIperCell.awk
#   inflating: STAR-2.7.10a/extras/scripts/tagXSstrandedData.awk
#   inflating: STAR-2.7.10a/extras/scripts/transcriptTypes.awk
#   inflating: STAR-2.7.10a/extras/scripts/transfragsFromBedGraph.awk
#    creating: STAR-2.7.10a/extras/tests/
#    creating: STAR-2.7.10a/extras/tests/scripts/
#   inflating: STAR-2.7.10a/extras/tests/scripts/checkCellReadsStats.awk
#   inflating: STAR-2.7.10a/extras/tests/scripts/checkCellReadsStats_vsBAM.awk
#   inflating: STAR-2.7.10a/extras/tests/scripts/checkCellReadsStats_vsMatrix.awk
#    creating: STAR-2.7.10a/source/
#   inflating: STAR-2.7.10a/source/AlignVsTranscript.h
#   inflating: STAR-2.7.10a/source/BAMbinSortByCoordinate.cpp
#   inflating: STAR-2.7.10a/source/BAMbinSortByCoordinate.h
#   inflating: STAR-2.7.10a/source/BAMbinSortUnmapped.cpp
#   inflating: STAR-2.7.10a/source/BAMbinSortUnmapped.h
#   inflating: STAR-2.7.10a/source/BAMfunctions.cpp
#   inflating: STAR-2.7.10a/source/BAMfunctions.h
#   inflating: STAR-2.7.10a/source/BAMoutput.cpp
#   inflating: STAR-2.7.10a/source/BAMoutput.h
#   inflating: STAR-2.7.10a/source/Chain.cpp
#   inflating: STAR-2.7.10a/source/Chain.h
#   inflating: STAR-2.7.10a/source/ChimericAlign.cpp
#   inflating: STAR-2.7.10a/source/ChimericAlign.h
#   inflating: STAR-2.7.10a/source/ChimericAlign_chimericBAMoutput.cpp
#   inflating: STAR-2.7.10a/source/ChimericAlign_chimericJunctionOutput.cpp
#   inflating: STAR-2.7.10a/source/ChimericAlign_chimericStitching.cpp
#   inflating: STAR-2.7.10a/source/ChimericDetection.cpp
#   inflating: STAR-2.7.10a/source/ChimericDetection.h
#   inflating: STAR-2.7.10a/source/ChimericDetection_chimericDetectionMult.cpp
#   inflating: STAR-2.7.10a/source/ChimericSegment.cpp
#   inflating: STAR-2.7.10a/source/ChimericSegment.h
#   inflating: STAR-2.7.10a/source/ChimericTranscript.h
#   inflating: STAR-2.7.10a/source/ClipCR4.cpp
#   inflating: STAR-2.7.10a/source/ClipCR4.h
#   inflating: STAR-2.7.10a/source/ClipMate.h
#   inflating: STAR-2.7.10a/source/ClipMate_clip.cpp
#   inflating: STAR-2.7.10a/source/ClipMate_clipChunk.cpp
#   inflating: STAR-2.7.10a/source/ClipMate_initialize.cpp
#   inflating: STAR-2.7.10a/source/ErrorWarning.cpp
#   inflating: STAR-2.7.10a/source/ErrorWarning.h
#   inflating: STAR-2.7.10a/source/GTF.cpp
#   inflating: STAR-2.7.10a/source/GTF.h
#   inflating: STAR-2.7.10a/source/GTF_superTranscript.cpp
#   inflating: STAR-2.7.10a/source/GTF_transcriptGeneSJ.cpp
#   inflating: STAR-2.7.10a/source/Genome.cpp
#   inflating: STAR-2.7.10a/source/Genome.h
#   inflating: STAR-2.7.10a/source/Genome_genomeGenerate.cpp
#   inflating: STAR-2.7.10a/source/Genome_genomeLoad.cpp
#   inflating: STAR-2.7.10a/source/Genome_genomeOutLoad.cpp
#   inflating: STAR-2.7.10a/source/Genome_insertSequences.cpp
#   inflating: STAR-2.7.10a/source/Genome_transformGenome.cpp
#   inflating: STAR-2.7.10a/source/GlobalVariables.cpp
#   inflating: STAR-2.7.10a/source/GlobalVariables.h
#   inflating: STAR-2.7.10a/source/InOutStreams.cpp
#   inflating: STAR-2.7.10a/source/InOutStreams.h
#   inflating: STAR-2.7.10a/source/IncludeDefine.h
#   inflating: STAR-2.7.10a/source/Makefile
#   inflating: STAR-2.7.10a/source/OutSJ.cpp
#   inflating: STAR-2.7.10a/source/OutSJ.h
#   inflating: STAR-2.7.10a/source/PackedArray.cpp
#   inflating: STAR-2.7.10a/source/PackedArray.h
#   inflating: STAR-2.7.10a/source/ParameterInfo.h
#   inflating: STAR-2.7.10a/source/Parameters.cpp
#   inflating: STAR-2.7.10a/source/Parameters.h
#   inflating: STAR-2.7.10a/source/ParametersChimeric.h
#   inflating: STAR-2.7.10a/source/ParametersChimeric_initialize.cpp
#   inflating: STAR-2.7.10a/source/ParametersClip.h
#   inflating: STAR-2.7.10a/source/ParametersClip_initialize.cpp
#   inflating: STAR-2.7.10a/source/ParametersGenome.cpp
#   inflating: STAR-2.7.10a/source/ParametersGenome.h
#   inflating: STAR-2.7.10a/source/ParametersSolo.cpp
#   inflating: STAR-2.7.10a/source/ParametersSolo.h
#   inflating: STAR-2.7.10a/source/Parameters_closeReadsFiles.cpp
#   inflating: STAR-2.7.10a/source/Parameters_openReadsFiles.cpp
#   inflating: STAR-2.7.10a/source/Parameters_readFilesInit.cpp
#   inflating: STAR-2.7.10a/source/Parameters_readSAMheader.cpp
#   inflating: STAR-2.7.10a/source/Parameters_samAttributes.cpp
#   inflating: STAR-2.7.10a/source/Quantifications.cpp
#   inflating: STAR-2.7.10a/source/Quantifications.h
#   inflating: STAR-2.7.10a/source/ReadAlign.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign.h
#   inflating: STAR-2.7.10a/source/ReadAlignChunk.cpp
#   inflating: STAR-2.7.10a/source/ReadAlignChunk.h
#   inflating: STAR-2.7.10a/source/ReadAlignChunk_mapChunk.cpp
#   inflating: STAR-2.7.10a/source/ReadAlignChunk_processChunks.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_CIGAR.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_alignBAM.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_assignAlignToWindow.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_calcCIGAR.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_chimericDetection.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_chimericDetectionOld.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_chimericDetectionOldOutput.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_chimericDetectionPEmerged.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_createExtendWindowsWithAlign.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_mapOneRead.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_mapOneReadSpliceGraph.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_mappedFilter.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_maxMappableLength2strands.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_multMapSelect.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_oneRead.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_outputAlignments.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_outputSpliceGraphSAM.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_outputTranscriptCIGARp.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_outputTranscriptSAM.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_outputTranscriptSJ.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_outputVariation.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_peOverlapMergeMap.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_quantTranscriptome.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_stitchPieces.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_stitchWindowSeeds.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_storeAligns.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_transformGenome.cpp
#   inflating: STAR-2.7.10a/source/ReadAlign_waspMap.cpp
#   inflating: STAR-2.7.10a/source/ReadAnnotations.h
#   inflating: STAR-2.7.10a/source/STAR.cpp
#   inflating: STAR-2.7.10a/source/SequenceFuns.cpp
#   inflating: STAR-2.7.10a/source/SequenceFuns.h
#   inflating: STAR-2.7.10a/source/SharedMemory.cpp
#   inflating: STAR-2.7.10a/source/SharedMemory.h
#    creating: STAR-2.7.10a/source/SimpleGoodTuring/
#   inflating: STAR-2.7.10a/source/SimpleGoodTuring/ReadMe.txt
#   inflating: STAR-2.7.10a/source/SimpleGoodTuring/sgt.h
#   inflating: STAR-2.7.10a/source/SjdbClass.h
#   inflating: STAR-2.7.10a/source/Solo.cpp
#   inflating: STAR-2.7.10a/source/Solo.h
#   inflating: STAR-2.7.10a/source/SoloBarcode.cpp
#   inflating: STAR-2.7.10a/source/SoloBarcode.h
#   inflating: STAR-2.7.10a/source/SoloBarcode_extractBarcode.cpp
#   inflating: STAR-2.7.10a/source/SoloCommon.h
#   inflating: STAR-2.7.10a/source/SoloFeature.cpp
#   inflating: STAR-2.7.10a/source/SoloFeature.h
#   inflating: STAR-2.7.10a/source/SoloFeatureTypes.h
#   inflating: STAR-2.7.10a/source/SoloFeature_addBAMtags.cpp
#   inflating: STAR-2.7.10a/source/SoloFeature_cellFiltering.cpp
#   inflating: STAR-2.7.10a/source/SoloFeature_collapseUMI_Graph.cpp
#   inflating: STAR-2.7.10a/source/SoloFeature_collapseUMIall_multiMappers.cpp
#   inflating: STAR-2.7.10a/source/SoloFeature_countCBgeneUMI.cpp
#   inflating: STAR-2.7.10a/source/SoloFeature_countSmartSeq.cpp
#   inflating: STAR-2.7.10a/source/SoloFeature_countVelocyto.cpp
#   inflating: STAR-2.7.10a/source/SoloFeature_emptyDrops_CR.cpp
#   inflating: STAR-2.7.10a/source/SoloFeature_loadRawMatrix.cpp
#   inflating: STAR-2.7.10a/source/SoloFeature_outputResults.cpp
#   inflating: STAR-2.7.10a/source/SoloFeature_processRecords.cpp
#   inflating: STAR-2.7.10a/source/SoloFeature_quantTranscript.cpp
#   inflating: STAR-2.7.10a/source/SoloFeature_redistributeReadsByCB.cpp
#   inflating: STAR-2.7.10a/source/SoloFeature_statsOutput.cpp
#   inflating: STAR-2.7.10a/source/SoloFeature_sumThreads.cpp
#   inflating: STAR-2.7.10a/source/SoloFilteredCells.h
#   inflating: STAR-2.7.10a/source/SoloRead.cpp
#   inflating: STAR-2.7.10a/source/SoloRead.h
#   inflating: STAR-2.7.10a/source/SoloReadBarcode.cpp
#   inflating: STAR-2.7.10a/source/SoloReadBarcode.h
#   inflating: STAR-2.7.10a/source/SoloReadBarcodeStats.h
#   inflating: STAR-2.7.10a/source/SoloReadBarcode_getCBandUMI.cpp
#   inflating: STAR-2.7.10a/source/SoloReadFeature.cpp
#   inflating: STAR-2.7.10a/source/SoloReadFeature.h
#   inflating: STAR-2.7.10a/source/SoloReadFeatureStats.h
#   inflating: STAR-2.7.10a/source/SoloReadFeature_inputRecords.cpp
#   inflating: STAR-2.7.10a/source/SoloReadFeature_record.cpp
#   inflating: STAR-2.7.10a/source/SoloRead_record.cpp
#   inflating: STAR-2.7.10a/source/SpliceGraph.cpp
#   inflating: STAR-2.7.10a/source/SpliceGraph.h
#   inflating: STAR-2.7.10a/source/SpliceGraph_findSuperTr.cpp
#   inflating: STAR-2.7.10a/source/SpliceGraph_swScoreSpliced.cpp
#   inflating: STAR-2.7.10a/source/SpliceGraph_swTraceBack.cpp
#   inflating: STAR-2.7.10a/source/Stats.cpp
#   inflating: STAR-2.7.10a/source/Stats.h
#   inflating: STAR-2.7.10a/source/SuffixArrayFuns.cpp
#   inflating: STAR-2.7.10a/source/SuffixArrayFuns.h
#   inflating: STAR-2.7.10a/source/SuperTranscriptome.cpp
#   inflating: STAR-2.7.10a/source/SuperTranscriptome.h
#   inflating: STAR-2.7.10a/source/Test.hpp
#   inflating: STAR-2.7.10a/source/ThreadControl.cpp
#   inflating: STAR-2.7.10a/source/ThreadControl.h
#   inflating: STAR-2.7.10a/source/TimeFunctions.cpp
#   inflating: STAR-2.7.10a/source/TimeFunctions.h
#   inflating: STAR-2.7.10a/source/Transcript.cpp
#   inflating: STAR-2.7.10a/source/Transcript.h
#   inflating: STAR-2.7.10a/source/Transcript_alignScore.cpp
#   inflating: STAR-2.7.10a/source/Transcript_convertGenomeCigar.cpp
#   inflating: STAR-2.7.10a/source/Transcript_generateCigarP.cpp
#   inflating: STAR-2.7.10a/source/Transcript_transformGenome.cpp
#   inflating: STAR-2.7.10a/source/Transcript_variationAdjust.cpp
#   inflating: STAR-2.7.10a/source/Transcript_variationOutput.cpp
#   inflating: STAR-2.7.10a/source/Transcriptome.cpp
#   inflating: STAR-2.7.10a/source/Transcriptome.h
#   inflating: STAR-2.7.10a/source/Transcriptome_alignExonOverlap.cpp
#   inflating: STAR-2.7.10a/source/Transcriptome_classifyAlign.cpp
#   inflating: STAR-2.7.10a/source/Transcriptome_geneCountsAddAlign.cpp
#   inflating: STAR-2.7.10a/source/Transcriptome_geneFullAlignOverlap.cpp
#   inflating: STAR-2.7.10a/source/Transcriptome_geneFullAlignOverlap_ExonOverIntron.cpp
#   inflating: STAR-2.7.10a/source/Transcriptome_quantAlign.cpp
#  extracting: STAR-2.7.10a/source/VERSION
#   inflating: STAR-2.7.10a/source/Variation.cpp
#   inflating: STAR-2.7.10a/source/Variation.h
#   inflating: STAR-2.7.10a/source/bamRemoveDuplicates.cpp
#   inflating: STAR-2.7.10a/source/bamRemoveDuplicates.h
#   inflating: STAR-2.7.10a/source/bamSortByCoordinate.cpp
#   inflating: STAR-2.7.10a/source/bamSortByCoordinate.h
#   inflating: STAR-2.7.10a/source/bam_cat.c
#   inflating: STAR-2.7.10a/source/bam_cat.h
#   inflating: STAR-2.7.10a/source/binarySearch2.cpp
#   inflating: STAR-2.7.10a/source/binarySearch2.h
#   inflating: STAR-2.7.10a/source/blocksOverlap.cpp
#   inflating: STAR-2.7.10a/source/blocksOverlap.h
#   inflating: STAR-2.7.10a/source/extendAlign.cpp
#   inflating: STAR-2.7.10a/source/extendAlign.h
#   inflating: STAR-2.7.10a/source/funCompareUintAndSuffixes.cpp
#   inflating: STAR-2.7.10a/source/funCompareUintAndSuffixes.h
#   inflating: STAR-2.7.10a/source/funCompareUintAndSuffixesMemcmp.cpp
#   inflating: STAR-2.7.10a/source/funCompareUintAndSuffixesMemcmp.h
#   inflating: STAR-2.7.10a/source/genomeGenerate.h
#   inflating: STAR-2.7.10a/source/genomeParametersWrite.cpp
#   inflating: STAR-2.7.10a/source/genomeParametersWrite.h
#   inflating: STAR-2.7.10a/source/genomeSAindex.cpp
#   inflating: STAR-2.7.10a/source/genomeSAindex.h
#   inflating: STAR-2.7.10a/source/genomeScanFastaFiles.cpp
#   inflating: STAR-2.7.10a/source/genomeScanFastaFiles.h
#    creating: STAR-2.7.10a/source/htslib/
#   inflating: STAR-2.7.10a/source/htslib/.gitignore
#   inflating: STAR-2.7.10a/source/htslib/.travis.yml
#   inflating: STAR-2.7.10a/source/htslib/Makefile
#   inflating: STAR-2.7.10a/source/htslib/README.md
#   inflating: STAR-2.7.10a/source/htslib/bgzf.c
#   inflating: STAR-2.7.10a/source/htslib/bgzip.c
#   inflating: STAR-2.7.10a/source/htslib/config.h
#    creating: STAR-2.7.10a/source/htslib/cram/
#   inflating: STAR-2.7.10a/source/htslib/cram/cram.h
#   inflating: STAR-2.7.10a/source/htslib/cram/cram_codecs.c
#   inflating: STAR-2.7.10a/source/htslib/cram/cram_codecs.h
#   inflating: STAR-2.7.10a/source/htslib/cram/cram_decode.c
#   inflating: STAR-2.7.10a/source/htslib/cram/cram_decode.h
#   inflating: STAR-2.7.10a/source/htslib/cram/cram_encode.c
#   inflating: STAR-2.7.10a/source/htslib/cram/cram_encode.h
#   inflating: STAR-2.7.10a/source/htslib/cram/cram_index.c
#   inflating: STAR-2.7.10a/source/htslib/cram/cram_index.h
#   inflating: STAR-2.7.10a/source/htslib/cram/cram_io.c
#   inflating: STAR-2.7.10a/source/htslib/cram/cram_io.h
#   inflating: STAR-2.7.10a/source/htslib/cram/cram_samtools.c
#   inflating: STAR-2.7.10a/source/htslib/cram/cram_samtools.h
#   inflating: STAR-2.7.10a/source/htslib/cram/cram_stats.c
#   inflating: STAR-2.7.10a/source/htslib/cram/cram_stats.h
#   inflating: STAR-2.7.10a/source/htslib/cram/cram_structs.h
#   inflating: STAR-2.7.10a/source/htslib/cram/files.c
#   inflating: STAR-2.7.10a/source/htslib/cram/mFILE.c
#   inflating: STAR-2.7.10a/source/htslib/cram/mFILE.h
#   inflating: STAR-2.7.10a/source/htslib/cram/md5.c
#   inflating: STAR-2.7.10a/source/htslib/cram/md5.h
#   inflating: STAR-2.7.10a/source/htslib/cram/misc.h
#   inflating: STAR-2.7.10a/source/htslib/cram/open_trace_file.c
#   inflating: STAR-2.7.10a/source/htslib/cram/open_trace_file.h
#   inflating: STAR-2.7.10a/source/htslib/cram/os.h
#   inflating: STAR-2.7.10a/source/htslib/cram/pooled_alloc.c
#   inflating: STAR-2.7.10a/source/htslib/cram/pooled_alloc.h
#   inflating: STAR-2.7.10a/source/htslib/cram/sam_header.c
#   inflating: STAR-2.7.10a/source/htslib/cram/sam_header.h
#   inflating: STAR-2.7.10a/source/htslib/cram/string_alloc.c
#   inflating: STAR-2.7.10a/source/htslib/cram/string_alloc.h
#   inflating: STAR-2.7.10a/source/htslib/cram/thread_pool.c
#   inflating: STAR-2.7.10a/source/htslib/cram/thread_pool.h
#   inflating: STAR-2.7.10a/source/htslib/cram/vlen.c
#   inflating: STAR-2.7.10a/source/htslib/cram/vlen.h
#   inflating: STAR-2.7.10a/source/htslib/cram/zfio.c
#   inflating: STAR-2.7.10a/source/htslib/cram/zfio.h
#   inflating: STAR-2.7.10a/source/htslib/faidx.5
#   inflating: STAR-2.7.10a/source/htslib/faidx.c
#   inflating: STAR-2.7.10a/source/htslib/hfile.c
#   inflating: STAR-2.7.10a/source/htslib/hfile_internal.h
#   inflating: STAR-2.7.10a/source/htslib/hfile_net.c
#   inflating: STAR-2.7.10a/source/htslib/hts.c
#   inflating: STAR-2.7.10a/source/htslib/htslib.mk
#    creating: STAR-2.7.10a/source/htslib/htslib/
#   inflating: STAR-2.7.10a/source/htslib/htslib/bgzf.h
#   inflating: STAR-2.7.10a/source/htslib/htslib/faidx.h
#   inflating: STAR-2.7.10a/source/htslib/htslib/hfile.h
#   inflating: STAR-2.7.10a/source/htslib/htslib/hts.h
#   inflating: STAR-2.7.10a/source/htslib/htslib/hts_defs.h
#   inflating: STAR-2.7.10a/source/htslib/htslib/kfunc.h
#   inflating: STAR-2.7.10a/source/htslib/htslib/khash.h
#   inflating: STAR-2.7.10a/source/htslib/htslib/khash_str2int.h
#   inflating: STAR-2.7.10a/source/htslib/htslib/klist.h
#   inflating: STAR-2.7.10a/source/htslib/htslib/knetfile.h
#   inflating: STAR-2.7.10a/source/htslib/htslib/kseq.h
#   inflating: STAR-2.7.10a/source/htslib/htslib/ksort.h
#   inflating: STAR-2.7.10a/source/htslib/htslib/kstdint.h
#   inflating: STAR-2.7.10a/source/htslib/htslib/kstring.h
#   inflating: STAR-2.7.10a/source/htslib/htslib/sam.h
#   inflating: STAR-2.7.10a/source/htslib/htslib/synced_bcf_reader.h
#   inflating: STAR-2.7.10a/source/htslib/htslib/tbx.h
#   inflating: STAR-2.7.10a/source/htslib/htslib/vcf.h
#   inflating: STAR-2.7.10a/source/htslib/htslib/vcf_sweep.h
#   inflating: STAR-2.7.10a/source/htslib/htslib/vcfutils.h
#   inflating: STAR-2.7.10a/source/htslib/htslib_vars.mk
#   inflating: STAR-2.7.10a/source/htslib/kfunc.c
#   inflating: STAR-2.7.10a/source/htslib/knetfile.c
#   inflating: STAR-2.7.10a/source/htslib/kstring.c
#   inflating: STAR-2.7.10a/source/htslib/sam.5
#   inflating: STAR-2.7.10a/source/htslib/sam.c
#   inflating: STAR-2.7.10a/source/htslib/synced_bcf_reader.c
#   inflating: STAR-2.7.10a/source/htslib/tabix.1
#   inflating: STAR-2.7.10a/source/htslib/tabix.c
#   inflating: STAR-2.7.10a/source/htslib/tbx.c
#   inflating: STAR-2.7.10a/source/htslib/vcf.5
#   inflating: STAR-2.7.10a/source/htslib/vcf.c
#   inflating: STAR-2.7.10a/source/htslib/vcf_sweep.c
#   inflating: STAR-2.7.10a/source/htslib/vcfutils.c
#   inflating: STAR-2.7.10a/source/insertSeqSA.cpp
#   inflating: STAR-2.7.10a/source/insertSeqSA.h
#   inflating: STAR-2.7.10a/source/mapThreadsSpawn.cpp
#   inflating: STAR-2.7.10a/source/mapThreadsSpawn.h
#    creating: STAR-2.7.10a/source/opal/
#   inflating: STAR-2.7.10a/source/opal/LICENSE
#   inflating: STAR-2.7.10a/source/opal/opal.cpp
#   inflating: STAR-2.7.10a/source/opal/opal.h
#   inflating: STAR-2.7.10a/source/opal/simde_avx2.h
#   inflating: STAR-2.7.10a/source/outputSJ.cpp
#   inflating: STAR-2.7.10a/source/outputSJ.h
#   inflating: STAR-2.7.10a/source/parametersDefault
#   inflating: STAR-2.7.10a/source/parametersDefault.xxd
#   inflating: STAR-2.7.10a/source/readBarcodeLoad.h
#   inflating: STAR-2.7.10a/source/readLoad.cpp
#   inflating: STAR-2.7.10a/source/readLoad.h
#   inflating: STAR-2.7.10a/source/samHeaders.cpp
#   inflating: STAR-2.7.10a/source/samHeaders.h
#   inflating: STAR-2.7.10a/source/serviceFuns.cpp
#   inflating: STAR-2.7.10a/source/signalFromBAM.cpp
#   inflating: STAR-2.7.10a/source/signalFromBAM.h
#   inflating: STAR-2.7.10a/source/sjAlignSplit.cpp
#   inflating: STAR-2.7.10a/source/sjAlignSplit.h
#   inflating: STAR-2.7.10a/source/sjdbBuildIndex.cpp
#   inflating: STAR-2.7.10a/source/sjdbBuildIndex.h
#   inflating: STAR-2.7.10a/source/sjdbInsertJunctions.cpp
#   inflating: STAR-2.7.10a/source/sjdbInsertJunctions.h
#   inflating: STAR-2.7.10a/source/sjdbLoadFromFiles.cpp
#   inflating: STAR-2.7.10a/source/sjdbLoadFromFiles.h
#   inflating: STAR-2.7.10a/source/sjdbLoadFromStream.cpp
#   inflating: STAR-2.7.10a/source/sjdbLoadFromStream.h
#   inflating: STAR-2.7.10a/source/sjdbPrepare.cpp
#   inflating: STAR-2.7.10a/source/sjdbPrepare.h
#   inflating: STAR-2.7.10a/source/soloInputFeatureUMI.cpp
#   inflating: STAR-2.7.10a/source/soloInputFeatureUMI.h
#   inflating: STAR-2.7.10a/source/sortSuffixesBucket.h
#   inflating: STAR-2.7.10a/source/stitchAlignToTranscript.cpp
#   inflating: STAR-2.7.10a/source/stitchAlignToTranscript.h
#   inflating: STAR-2.7.10a/source/stitchGapIndel.cpp
#   inflating: STAR-2.7.10a/source/stitchWindowAligns.cpp
#   inflating: STAR-2.7.10a/source/stitchWindowAligns.h
#   inflating: STAR-2.7.10a/source/streamFuns.cpp
#   inflating: STAR-2.7.10a/source/streamFuns.h
#   inflating: STAR-2.7.10a/source/stringSubstituteAll.cpp
#   inflating: STAR-2.7.10a/source/stringSubstituteAll.h
#   inflating: STAR-2.7.10a/source/sysRemoveDir.cpp
#   inflating: STAR-2.7.10a/source/sysRemoveDir.h
#   inflating: STAR-2.7.10a/source/twoPassRunPass1.cpp
#   inflating: STAR-2.7.10a/source/twoPassRunPass1.h
# make -C htslib lib-static
# make[1]: Entering directory '/content/STAR-2.7.10a/source/htslib'
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o kfunc.o kfunc.c
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o knetfile.o knetfile.c
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o kstring.o kstring.c
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o bgzf.o bgzf.c
# bgzf.c: In function ‘bgzf_write’:
# bgzf.c:733:5: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#   733 |     if ( !fp->is_compressed )
#       |     ^~
# bgzf.c:736:9: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#   736 |         const uint8_t *input = (const uint8_t*)data;
#       |         ^~~~~
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o faidx.o faidx.c
# faidx.c: In function ‘fai_load’:
# faidx.c:265:5: warning: this ‘else’ clause does not guard... [-Wmisleading-indentation]
#   265 |     else
#       |     ^~~~
# faidx.c:268:9: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘else’
#   268 |         if (fp == 0) {
#       |         ^~
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o hfile.o hfile.c
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o hfile_net.o hfile_net.c
# echo '#define HTS_VERSION "0.0.1"' > version.h
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o hts.o hts.c
# hts.c: In function ‘hts_idx_init’:
# hts.c:522:63: warning: overflow in conversion from ‘uint32_t’ {aka ‘unsigned int’} to ‘int’ changes value from ‘idx->z.last_bin = 4294967295’ to ‘-1’ [-Woverflow]
#   522 |         idx->z.save_bin = idx->z.save_tid = idx->z.last_tid = idx->z.last_bin = 0xffffffffu;
#       |                                                               ^~~
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o sam.o sam.c
# In file included from /usr/include/string.h:535,
#                  from sam.c:3:
# In function ‘strncpy’,
#     inlined from ‘bam_hdr_write’ at sam.c:130:2:
# /usr/include/x86_64-linux-gnu/bits/string_fortified.h:95:10: warning: ‘__builtin_strncpy’ output truncated before terminating nul copying 4 bytes from a string of the same length [-Wstringop-truncation]
#    95 |   return __builtin___strncpy_chk (__dest, __src, __len,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    96 |                                   __glibc_objsize (__dest));
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o synced_bcf_reader.o synced_bcf_reader.c
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o vcf_sweep.o vcf_sweep.c
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o tbx.o tbx.c
# tbx.c: In function ‘tbx_seqnames’:
# tbx.c:285:5: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#   285 |     for (tid=0; tid<m; tid++)
#       |     ^~~
# tbx.c:287:9: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#   287 |         *n = m;
#       |         ^
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o vcf.o vcf.c
# vcf.c: In function ‘vcf_format’:
# vcf.c:1909:25: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#  1909 |                         if ( !first ) kputc(';', s); first = 0;
#       |                         ^~
# vcf.c:1909:54: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#  1909 |                         if ( !first ) kputc(';', s); first = 0;
#       |                                                      ^~~~~
# vcf.c:1948:21: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#  1948 |                     if (!first) kputc(':', s); first = 0;
#       |                     ^~
# vcf.c:1948:48: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#  1948 |                     if (!first) kputc(':', s); first = 0;
#       |                                                ^~~~~
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o vcfutils.o vcfutils.c
# In file included from htslib/vcf.h:12,
#                  from htslib/vcfutils.h:8,
#                  from vcfutils.c:1:
# vcfutils.c: In function ‘bcf_remove_alleles’:
# vcfutils.c:291:25: warning: suggest parentheses around assignment used as truth value [-Wparentheses]
#   291 |                 assert( n=nG_ori );
#       |                         ^
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o cram/cram_codecs.o cram/cram_codecs.c
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o cram/cram_decode.o cram/cram_decode.c
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o cram/cram_encode.o cram/cram_encode.c
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o cram/cram_index.o cram/cram_index.c
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o cram/cram_io.o cram/cram_io.c
# cram/cram_io.c: In function ‘cram_populate_ref’:
# cram/cram_io.c:1529:34: warning: ‘.tmp_’ directive writing 5 bytes into a region of size between 1 and 4096 [-Wformat-overflow=]
#  1529 |             sprintf(path_tmp, "%s.tmp_%d", path, /*getpid(),*/ i);
#       |                                  ^~~~~
# cram/cram_io.c:1529:31: note: directive argument in the range [0, 2147483647]
#  1529 |             sprintf(path_tmp, "%s.tmp_%d", path, /*getpid(),*/ i);
#       |                               ^~~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from cram/cram_io.c:51:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 7 and 4111 bytes into a destination of size 4096
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# In file included from /usr/include/string.h:535,
#                  from cram/cram_io.c:55:
# In function ‘strncpy’,
#     inlined from ‘full_path’ at cram/cram_io.c:2917:6,
#     inlined from ‘cram_write_SAM_hdr’ at cram/cram_io.c:2987:3:
# /usr/include/x86_64-linux-gnu/bits/string_fortified.h:95:10: warning: ‘__builtin_strncpy’ specified bound 4096 equals destination size [-Wstringop-truncation]
#    95 |   return __builtin___strncpy_chk (__dest, __src, __len,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    96 |                                   __glibc_objsize (__dest));
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~
# In function ‘strncpy’,
#     inlined from ‘full_path’ at cram/cram_io.c:2909:2,
#     inlined from ‘cram_write_SAM_hdr’ at cram/cram_io.c:2987:3:
# /usr/include/x86_64-linux-gnu/bits/string_fortified.h:95:10: warning: ‘__builtin_strncpy’ specified bound 4096 equals destination size [-Wstringop-truncation]
#    95 |   return __builtin___strncpy_chk (__dest, __src, __len,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    96 |                                   __glibc_objsize (__dest));
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~
# In function ‘strncpy’,
#     inlined from ‘cram_dopen’ at cram/cram_io.c:3291:2:
# /usr/include/x86_64-linux-gnu/bits/string_fortified.h:95:10: warning: ‘__builtin_strncpy’ specified bound 20 equals destination size [-Wstringop-truncation]
#    95 |   return __builtin___strncpy_chk (__dest, __src, __len,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    96 |                                   __glibc_objsize (__dest));
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o cram/cram_samtools.o cram/cram_samtools.c
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o cram/cram_stats.o cram/cram_stats.c
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o cram/files.o cram/files.c
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o cram/mFILE.o cram/mFILE.c
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o cram/md5.o cram/md5.c
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o cram/open_trace_file.o cram/open_trace_file.c
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o cram/pooled_alloc.o cram/pooled_alloc.c
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o cram/sam_header.o cram/sam_header.c
# In file included from cram/sam_header.c:36:
# cram/sam_header.c: In function ‘sam_hdr_add_lines’:
# cram/sam_header.c:328:20: warning: suggest parentheses around assignment used as truth value [-Wparentheses]
#   328 |             assert(p->next = t);
#       |                    ^
# cram/sam_header.c: In function ‘sam_hdr_vadd’:
# cram/sam_header.c:449:16: warning: suggest parentheses around assignment used as truth value [-Wparentheses]
#   449 |         assert(p->next = t);
#       |                ^
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o cram/string_alloc.o cram/string_alloc.c
# In file included from /usr/include/string.h:535,
#                  from cram/string_alloc.c:39:
# In function ‘strncpy’,
#     inlined from ‘string_ndup’ at cram/string_alloc.c:149:5,
#     inlined from ‘string_dup’ at cram/string_alloc.c:141:12:
# /usr/include/x86_64-linux-gnu/bits/string_fortified.h:95:10: warning: ‘__builtin_strncpy’ output truncated before terminating nul copying as many bytes from a string as its length [-Wstringop-truncation]
#    95 |   return __builtin___strncpy_chk (__dest, __src, __len,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    96 |                                   __glibc_objsize (__dest));
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~
# cram/string_alloc.c: In function ‘string_dup’:
# cram/string_alloc.c:141:12: note: length computed here
#   141 |     return string_ndup(a_str, instr, strlen(instr));
#       |            ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o cram/thread_pool.o cram/thread_pool.c
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o cram/vlen.o cram/vlen.c
# cram/vlen.c: In function ‘vflen’:
# cram/vlen.c:121:9: warning: variable ‘i’ set but not used [-Wunused-but-set-variable]
#   121 |     int i;
#       |         ^
# cc -g -Wall -O2  -I. -DSAMTOOLS=1 -c -o cram/zfio.o cram/zfio.c
# ar -rc libhts.a kfunc.o knetfile.o kstring.o bgzf.o faidx.o hfile.o hfile_net.o hts.o sam.o synced_bcf_reader.o vcf_sweep.o tbx.o vcf.o vcfutils.o cram/cram_codecs.o cram/cram_decode.o cram/cram_encode.o cram/cram_index.o cram/cram_io.o cram/cram_samtools.o cram/cram_stats.o cram/files.o cram/mFILE.o cram/md5.o cram/open_trace_file.o cram/pooled_alloc.o cram/sam_header.o cram/string_alloc.o cram/thread_pool.o cram/vlen.o cram/zfio.o
# ranlib libhts.a
# make[1]: Leaving directory '/content/STAR-2.7.10a/source/htslib'
# echo BAMbinSortByCoordinate.cpp BAMbinSortUnmapped.cpp BAMfunctions.cpp BAMoutput.cpp bamRemoveDuplicates.cpp bamSortByCoordinate.cpp binarySearch2.cpp blocksOverlap.cpp Chain.cpp ChimericAlign_chimericBAMoutput.cpp ChimericAlign_chimericJunctionOutput.cpp ChimericAlign_chimericStitching.cpp ChimericAlign.cpp ChimericDetection_chimericDetectionMult.cpp ChimericDetection.cpp ChimericSegment.cpp ClipCR4.cpp ClipMate_clipChunk.cpp ClipMate_clip.cpp ClipMate_initialize.cpp ErrorWarning.cpp extendAlign.cpp funCompareUintAndSuffixes.cpp funCompareUintAndSuffixesMemcmp.cpp Genome.cpp Genome_genomeGenerate.cpp Genome_genomeLoad.cpp Genome_genomeOutLoad.cpp Genome_insertSequences.cpp genomeParametersWrite.cpp genomeSAindex.cpp genomeScanFastaFiles.cpp Genome_transformGenome.cpp GlobalVariables.cpp GTF.cpp GTF_superTranscript.cpp GTF_transcriptGeneSJ.cpp InOutStreams.cpp insertSeqSA.cpp mapThreadsSpawn.cpp outputSJ.cpp OutSJ.cpp PackedArray.cpp ParametersChimeric_initialize.cpp ParametersClip_initialize.cpp Parameters_closeReadsFiles.cpp Parameters.cpp ParametersGenome.cpp Parameters_openReadsFiles.cpp Parameters_readFilesInit.cpp Parameters_readSAMheader.cpp Parameters_samAttributes.cpp ParametersSolo.cpp Quantifications.cpp ReadAlign_alignBAM.cpp ReadAlign_assignAlignToWindow.cpp ReadAlign_calcCIGAR.cpp ReadAlign_chimericDetection.cpp ReadAlign_chimericDetectionOld.cpp ReadAlign_chimericDetectionOldOutput.cpp ReadAlign_chimericDetectionPEmerged.cpp ReadAlignChunk.cpp ReadAlignChunk_mapChunk.cpp ReadAlignChunk_processChunks.cpp ReadAlign_CIGAR.cpp ReadAlign.cpp ReadAlign_createExtendWindowsWithAlign.cpp ReadAlign_mapOneRead.cpp ReadAlign_mapOneReadSpliceGraph.cpp ReadAlign_mappedFilter.cpp ReadAlign_maxMappableLength2strands.cpp ReadAlign_multMapSelect.cpp ReadAlign_oneRead.cpp ReadAlign_outputAlignments.cpp ReadAlign_outputSpliceGraphSAM.cpp ReadAlign_outputTranscriptCIGARp.cpp ReadAlign_outputTranscriptSAM.cpp ReadAlign_outputTranscriptSJ.cpp ReadAlign_outputVariation.cpp ReadAlign_peOverlapMergeMap.cpp ReadAlign_quantTranscriptome.cpp ReadAlign_stitchPieces.cpp ReadAlign_stitchWindowSeeds.cpp ReadAlign_storeAligns.cpp ReadAlign_transformGenome.cpp ReadAlign_waspMap.cpp readLoad.cpp samHeaders.cpp SequenceFuns.cpp serviceFuns.cpp SharedMemory.cpp signalFromBAM.cpp sjAlignSplit.cpp sjdbBuildIndex.cpp sjdbInsertJunctions.cpp sjdbLoadFromFiles.cpp sjdbLoadFromStream.cpp sjdbPrepare.cpp SoloBarcode.cpp SoloBarcode_extractBarcode.cpp Solo.cpp SoloFeature_addBAMtags.cpp SoloFeature_cellFiltering.cpp SoloFeature_collapseUMIall_multiMappers.cpp SoloFeature_collapseUMI_Graph.cpp SoloFeature_countCBgeneUMI.cpp SoloFeature_countSmartSeq.cpp SoloFeature_countVelocyto.cpp SoloFeature.cpp SoloFeature_emptyDrops_CR.cpp SoloFeature_loadRawMatrix.cpp SoloFeature_outputResults.cpp SoloFeature_processRecords.cpp SoloFeature_quantTranscript.cpp SoloFeature_redistributeReadsByCB.cpp SoloFeature_statsOutput.cpp SoloFeature_sumThreads.cpp soloInputFeatureUMI.cpp SoloReadBarcode.cpp SoloReadBarcode_getCBandUMI.cpp SoloRead.cpp SoloReadFeature.cpp SoloReadFeature_inputRecords.cpp SoloReadFeature_record.cpp SoloRead_record.cpp SpliceGraph.cpp SpliceGraph_findSuperTr.cpp SpliceGraph_swScoreSpliced.cpp SpliceGraph_swTraceBack.cpp STAR.cpp Stats.cpp stitchAlignToTranscript.cpp stitchGapIndel.cpp stitchWindowAligns.cpp streamFuns.cpp stringSubstituteAll.cpp SuffixArrayFuns.cpp SuperTranscriptome.cpp sysRemoveDir.cpp ThreadControl.cpp TimeFunctions.cpp Transcript_alignScore.cpp Transcript_convertGenomeCigar.cpp Transcript.cpp Transcript_generateCigarP.cpp Transcriptome_alignExonOverlap.cpp Transcriptome_classifyAlign.cpp Transcriptome.cpp Transcriptome_geneCountsAddAlign.cpp Transcriptome_geneFullAlignOverlap.cpp Transcriptome_geneFullAlignOverlap_ExonOverIntron.cpp Transcriptome_quantAlign.cpp Transcript_transformGenome.cpp Transcript_variationAdjust.cpp Transcript_variationOutput.cpp twoPassRunPass1.cpp Variation.cpp bam_cat.c
# BAMbinSortByCoordinate.cpp BAMbinSortUnmapped.cpp BAMfunctions.cpp BAMoutput.cpp bamRemoveDuplicates.cpp bamSortByCoordinate.cpp binarySearch2.cpp blocksOverlap.cpp Chain.cpp ChimericAlign_chimericBAMoutput.cpp ChimericAlign_chimericJunctionOutput.cpp ChimericAlign_chimericStitching.cpp ChimericAlign.cpp ChimericDetection_chimericDetectionMult.cpp ChimericDetection.cpp ChimericSegment.cpp ClipCR4.cpp ClipMate_clipChunk.cpp ClipMate_clip.cpp ClipMate_initialize.cpp ErrorWarning.cpp extendAlign.cpp funCompareUintAndSuffixes.cpp funCompareUintAndSuffixesMemcmp.cpp Genome.cpp Genome_genomeGenerate.cpp Genome_genomeLoad.cpp Genome_genomeOutLoad.cpp Genome_insertSequences.cpp genomeParametersWrite.cpp genomeSAindex.cpp genomeScanFastaFiles.cpp Genome_transformGenome.cpp GlobalVariables.cpp GTF.cpp GTF_superTranscript.cpp GTF_transcriptGeneSJ.cpp InOutStreams.cpp insertSeqSA.cpp mapThreadsSpawn.cpp outputSJ.cpp OutSJ.cpp PackedArray.cpp ParametersChimeric_initialize.cpp ParametersClip_initialize.cpp Parameters_closeReadsFiles.cpp Parameters.cpp ParametersGenome.cpp Parameters_openReadsFiles.cpp Parameters_readFilesInit.cpp Parameters_readSAMheader.cpp Parameters_samAttributes.cpp ParametersSolo.cpp Quantifications.cpp ReadAlign_alignBAM.cpp ReadAlign_assignAlignToWindow.cpp ReadAlign_calcCIGAR.cpp ReadAlign_chimericDetection.cpp ReadAlign_chimericDetectionOld.cpp ReadAlign_chimericDetectionOldOutput.cpp ReadAlign_chimericDetectionPEmerged.cpp ReadAlignChunk.cpp ReadAlignChunk_mapChunk.cpp ReadAlignChunk_processChunks.cpp ReadAlign_CIGAR.cpp ReadAlign.cpp ReadAlign_createExtendWindowsWithAlign.cpp ReadAlign_mapOneRead.cpp ReadAlign_mapOneReadSpliceGraph.cpp ReadAlign_mappedFilter.cpp ReadAlign_maxMappableLength2strands.cpp ReadAlign_multMapSelect.cpp ReadAlign_oneRead.cpp ReadAlign_outputAlignments.cpp ReadAlign_outputSpliceGraphSAM.cpp ReadAlign_outputTranscriptCIGARp.cpp ReadAlign_outputTranscriptSAM.cpp ReadAlign_outputTranscriptSJ.cpp ReadAlign_outputVariation.cpp ReadAlign_peOverlapMergeMap.cpp ReadAlign_quantTranscriptome.cpp ReadAlign_stitchPieces.cpp ReadAlign_stitchWindowSeeds.cpp ReadAlign_storeAligns.cpp ReadAlign_transformGenome.cpp ReadAlign_waspMap.cpp readLoad.cpp samHeaders.cpp SequenceFuns.cpp serviceFuns.cpp SharedMemory.cpp signalFromBAM.cpp sjAlignSplit.cpp sjdbBuildIndex.cpp sjdbInsertJunctions.cpp sjdbLoadFromFiles.cpp sjdbLoadFromStream.cpp sjdbPrepare.cpp SoloBarcode.cpp SoloBarcode_extractBarcode.cpp Solo.cpp SoloFeature_addBAMtags.cpp SoloFeature_cellFiltering.cpp SoloFeature_collapseUMIall_multiMappers.cpp SoloFeature_collapseUMI_Graph.cpp SoloFeature_countCBgeneUMI.cpp SoloFeature_countSmartSeq.cpp SoloFeature_countVelocyto.cpp SoloFeature.cpp SoloFeature_emptyDrops_CR.cpp SoloFeature_loadRawMatrix.cpp SoloFeature_outputResults.cpp SoloFeature_processRecords.cpp SoloFeature_quantTranscript.cpp SoloFeature_redistributeReadsByCB.cpp SoloFeature_statsOutput.cpp SoloFeature_sumThreads.cpp soloInputFeatureUMI.cpp SoloReadBarcode.cpp SoloReadBarcode_getCBandUMI.cpp SoloRead.cpp SoloReadFeature.cpp SoloReadFeature_inputRecords.cpp SoloReadFeature_record.cpp SoloRead_record.cpp SpliceGraph.cpp SpliceGraph_findSuperTr.cpp SpliceGraph_swScoreSpliced.cpp SpliceGraph_swTraceBack.cpp STAR.cpp Stats.cpp stitchAlignToTranscript.cpp stitchGapIndel.cpp stitchWindowAligns.cpp streamFuns.cpp stringSubstituteAll.cpp SuffixArrayFuns.cpp SuperTranscriptome.cpp sysRemoveDir.cpp ThreadControl.cpp TimeFunctions.cpp Transcript_alignScore.cpp Transcript_convertGenomeCigar.cpp Transcript.cpp Transcript_generateCigarP.cpp Transcriptome_alignExonOverlap.cpp Transcriptome_classifyAlign.cpp Transcriptome.cpp Transcriptome_geneCountsAddAlign.cpp Transcriptome_geneFullAlignOverlap.cpp Transcriptome_geneFullAlignOverlap_ExonOverIntron.cpp Transcriptome_quantAlign.cpp Transcript_transformGenome.cpp Transcript_variationAdjust.cpp Transcript_variationOutput.cpp twoPassRunPass1.cpp Variation.cpp bam_cat.c
# 'rm' -f ./Depend.list
# ...
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra ReadAlign_createExtendWindowsWithAlign.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra ReadAlign_assignAlignToWindow.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra ReadAlign_oneRead.cpp
# ReadAlign_oneRead.cpp: In member function ‘int ReadAlign::oneRead()’:
# ReadAlign_oneRead.cpp:23:21: warning: ‘*readStatus[0]’ may be used uninitialized [-Wmaybe-uninitialized]
#    23 |     if (readStatus[0]==-1) {//finished with the stream
#       |         ~~~~~~~~~~~~^
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra ReadAlign_stitchWindowSeeds.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra ReadAlign_peOverlapMergeMap.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra ReadAlign_mappedFilter.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra ParametersChimeric_initialize.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra ReadAlign_chimericDetection.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra ReadAlign_chimericDetectionOld.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra ReadAlign_chimericDetectionOldOutput.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra ChimericDetection.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra ChimericDetection_chimericDetectionMult.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra ReadAlign_chimericDetectionPEmerged.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra stitchWindowAligns.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra extendAlign.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra stitchAlignToTranscript.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra ChimericAlign_chimericJunctionOutput.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra ChimericAlign_chimericBAMoutput.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra ChimericAlign_chimericStitching.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra Genome_genomeGenerate.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra genomeParametersWrite.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra genomeScanFastaFiles.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra genomeSAindex.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra Genome_insertSequences.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra insertSeqSA.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra funCompareUintAndSuffixes.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra funCompareUintAndSuffixesMemcmp.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra TimeFunctions.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra ErrorWarning.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra streamFuns.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra stringSubstituteAll.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra Transcriptome.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra Transcriptome_quantAlign.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra Transcriptome_geneFullAlignOverlap.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra ReadAlign_quantTranscriptome.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra Quantifications.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra Transcriptome_geneCountsAddAlign.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra sjdbLoadFromFiles.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra sjdbLoadFromStream.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra sjdbPrepare.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra sjdbBuildIndex.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra sjdbInsertJunctions.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra mapThreadsSpawn.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra Parameters_readFilesInit.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra Parameters_readSAMheader.cpp
# Parameters_readSAMheader.cpp: In member function ‘void Parameters::readSAMheader(std::string, std::vector<std::__cxx11::basic_string<char> >)’:
# Parameters_readSAMheader.cpp:32:15: warning: ignoring return value of ‘int system(const char*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#    32 |         system(com1.c_str());
#       |         ~~~~~~^~~~~~~~~~~~~~
# g++ -c  -pipe -Wall -Wextra -O3 bam_cat.c
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra serviceFuns.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra BAMoutput.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra BAMfunctions.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra ReadAlign_alignBAM.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra BAMbinSortByCoordinate.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra signalFromBAM.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra bamRemoveDuplicates.cpp
# g++ -c   -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra BAMbinSortUnmapped.cpp
# g++ -o STAR  -O3 -std=c++11 -fopenmp -D'COMPILATION_TIME_PLACE="2025-11-11T05:09:48+00:00 f28f9d2ec208:/content/STAR-2.7.10a/source"' -D'GIT_BRANCH_COMMIT_DIFF=""' -pipe -Wall -Wextra SoloFeature_collapseUMI_Graph.o SoloFeature_collapseUMIall_multiMappers.o ParametersClip_initialize.o ClipMate_clip.o ClipCR4.o opal/opal.o ClipMate_clipChunk.o ClipMate_initialize.o SoloFeature_loadRawMatrix.o SoloFeature_emptyDrops_CR.o soloInputFeatureUMI.o SoloFeature_countSmartSeq.o SoloFeature_redistributeReadsByCB.o SoloFeature_quantTranscript.o SoloFeature_sumThreads.o SoloFeature_countVelocyto.o SoloFeature_countCBgeneUMI.o Transcriptome_classifyAlign.o Transcriptome_geneFullAlignOverlap_ExonOverIntron.o Transcriptome_alignExonOverlap.cpp SoloFeature_cellFiltering.o SoloFeature_statsOutput.o bamSortByCoordinate.o SoloBarcode.o ParametersSolo.o SoloRead.o SoloRead_record.o SoloReadBarcode.o SoloReadBarcode_getCBandUMI.o SoloBarcode_extractBarcode.o SoloReadFeature.o SoloReadFeature_record.o SoloReadFeature_inputRecords.o Solo.o SoloFeature.o SoloFeature_outputResults.o SoloFeature_processRecords.o SoloFeature_addBAMtags.o ReadAlign_transformGenome.o Genome_transformGenome.o Transcript_convertGenomeCigar.o twoPassRunPass1.o samHeaders.o Genome_genomeLoad.o Genome_genomeOutLoad.o Transcript_transformGenome.o ReadAlign_outputSpliceGraphSAM.o ReadAlign_mapOneReadSpliceGraph.o SpliceGraph.o SpliceGraph_swScoreSpliced.o SpliceGraph_swTraceBack.o SpliceGraph_findSuperTr.o sjAlignSplit.o GTF.o GTF_transcriptGeneSJ.o GTF_superTranscript.o SuperTranscriptome.o ReadAlign_outputAlignments.o ReadAlign.o STAR.o SharedMemory.o PackedArray.o SuffixArrayFuns.o Parameters.o Parameters_samAttributes.o InOutStreams.o SequenceFuns.o Genome.o ParametersGenome.o Stats.o Transcript.o Transcript_alignScore.o Transcript_generateCigarP.o Chain.o Transcript_variationAdjust.o Variation.o ReadAlign_waspMap.o ReadAlign_storeAligns.o ReadAlign_stitchPieces.o ReadAlign_multMapSelect.o ReadAlign_mapOneRead.o readLoad.o ReadAlignChunk.o ReadAlignChunk_processChunks.o ReadAlignChunk_mapChunk.o OutSJ.o outputSJ.o blocksOverlap.o ThreadControl.o sysRemoveDir.o ReadAlign_maxMappableLength2strands.o binarySearch2.o ReadAlign_outputTranscriptSAM.o ReadAlign_outputTranscriptSJ.o ReadAlign_outputTranscriptCIGARp.o ReadAlign_calcCIGAR.cpp ReadAlign_createExtendWindowsWithAlign.o ReadAlign_assignAlignToWindow.o ReadAlign_oneRead.o ReadAlign_stitchWindowSeeds.o ReadAlign_peOverlapMergeMap.o ReadAlign_mappedFilter.o ParametersChimeric_initialize.o ReadAlign_chimericDetection.o ReadAlign_chimericDetectionOld.o ReadAlign_chimericDetectionOldOutput.o ChimericDetection.o ChimericDetection_chimericDetectionMult.o ReadAlign_chimericDetectionPEmerged.o stitchWindowAligns.o extendAlign.o stitchAlignToTranscript.o ChimericSegment.cpp ChimericAlign.cpp ChimericAlign_chimericJunctionOutput.o ChimericAlign_chimericBAMoutput.o ChimericAlign_chimericStitching.o Genome_genomeGenerate.o genomeParametersWrite.o genomeScanFastaFiles.o genomeSAindex.o Genome_insertSequences.o insertSeqSA.o funCompareUintAndSuffixes.o funCompareUintAndSuffixesMemcmp.o TimeFunctions.o ErrorWarning.o streamFuns.o stringSubstituteAll.o Transcriptome.o Transcriptome_quantAlign.o Transcriptome_geneFullAlignOverlap.o ReadAlign_quantTranscriptome.o Quantifications.o Transcriptome_geneCountsAddAlign.o sjdbLoadFromFiles.o sjdbLoadFromStream.o sjdbPrepare.o sjdbBuildIndex.o sjdbInsertJunctions.o mapThreadsSpawn.o Parameters_readFilesInit.o Parameters_openReadsFiles.cpp Parameters_closeReadsFiles.cpp Parameters_readSAMheader.o bam_cat.o serviceFuns.o GlobalVariables.cpp BAMoutput.o BAMfunctions.o ReadAlign_alignBAM.o BAMbinSortByCoordinate.o signalFromBAM.o bamRemoveDuplicates.o BAMbinSortUnmapped.o  -pthread -Lhtslib -Bstatic -lhts -Bdynamic -lz
# Parameters_openReadsFiles.cpp: In member function ‘void Parameters::openReadsFiles()’:
# Parameters_openReadsFiles.cpp:25:20: warning: variable ‘imate’ might be clobbered by ‘longjmp’ or ‘vfork’ [-Wclobbered]
#    25 |          for (uint imate=0;imate<readFilesNames.size();imate++) {//open readIn files
#       |                    ^~~~~

# %%
# Step 1: Download FASTQ Files from SRA
# Download and convert SRR11548957 to paired-end FASTQ files
# !prefetch SRR11548957
# !fasterq-dump SRR11548957 --split-files
# Out:
# 2025-11-11T05:14:13 prefetch.2.11.3: Current preference is set to retrieve SRA Normalized Format files with full base quality scores.
# 2025-11-11T05:14:14 prefetch.2.11.3: 1) 'SRR11548957' is found locally
# 2025-11-11T05:14:14 prefetch.2.11.3: 'SRR11548957' has 0 unresolved dependencies
# spots read      : 1,792,464
# reads read      : 3,584,928
# reads written   : 3,584,928

# %%
# Step 2: Prepare Reference Genome (chr22)
# Create reference directory and download chr22 from Ensembl
# !mkdir -p reference
# !wget -P reference ftp://ftp.ensembl.org/pub/release-109/fasta/homo_sapiens/dna/Homo_sapiens.GRCh38.dna.chromosome.22.fa.gz
# !wget -P reference ftp://ftp.ensembl.org/pub/release-109/gtf/homo_sapiens/Homo_sapiens.GRCh38.109.gtf.gz

# Unzip the FASTA and GTF files
# !gunzip reference/Homo_sapiens.GRCh38.dna.chromosome.22.fa.gz
# !gunzip reference/Homo_sapiens.GRCh38.109.gtf.gz
# Out:
# --2025-11-11 05:16:00--  ftp://ftp.ensembl.org/pub/release-109/fasta/homo_sapiens/dna/Homo_sapiens.GRCh38.dna.chromosome.22.fa.gz
#            => ‘reference/Homo_sapiens.GRCh38.dna.chromosome.22.fa.gz’
# Resolving ftp.ensembl.org (ftp.ensembl.org)... 193.62.193.169
# Connecting to ftp.ensembl.org (ftp.ensembl.org)|193.62.193.169|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/release-109/fasta/homo_sapiens/dna ... done.
# ==> SIZE Homo_sapiens.GRCh38.dna.chromosome.22.fa.gz ... 11389810
# ==> PASV ... done.    ==> RETR Homo_sapiens.GRCh38.dna.chromosome.22.fa.gz ... done.
# Length: 11389810 (11M) (unauthoritative)
#
# Homo_sapiens.GRCh38 100%[===================>]  10.86M  9.30MB/s    in 1.2s
#
# 2025-11-11 05:16:03 (9.30 MB/s) - ‘reference/Homo_sapiens.GRCh38.dna.chromosome.22.fa.gz’ saved [11389810]
#
# --2025-11-11 05:16:03--  ftp://ftp.ensembl.org/pub/release-109/gtf/homo_sapiens/Homo_sapiens.GRCh38.109.gtf.gz
#            => ‘reference/Homo_sapiens.GRCh38.109.gtf.gz’
# Resolving ftp.ensembl.org (ftp.ensembl.org)... 193.62.193.169
# Connecting to ftp.ensembl.org (ftp.ensembl.org)|193.62.193.169|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/release-109/gtf/homo_sapiens ... done.
# ==> SIZE Homo_sapiens.GRCh38.109.gtf.gz ... 54258835
# ==> PASV ... done.    ==> RETR Homo_sapiens.GRCh38.109.gtf.gz ... done.
# Length: 54258835 (52M) (unauthoritative)
#
# Homo_sapiens.GRCh38 100%[===================>]  51.75M  20.1MB/s    in 2.6s
#
# 2025-11-11 05:16:07 (20.1 MB/s) - ‘reference/Homo_sapiens.GRCh38.109.gtf.gz’ saved [54258835]
#
# gzip: reference/Homo_sapiens.GRCh38.dna.chromosome.22.fa already exists; do you wish to overwrite (y or n)? n
# 	not overwritten

# %%
#  Step 3: Generate STAR Genome Index
# Create index directory and build genome index
# !mkdir -p star_index
# !/content/STAR-2.7.10a/bin/Linux_x86_64_static/STAR \
    --runThreadN 4 \
    --runMode genomeGenerate \
    --genomeDir star_index \
    --genomeFastaFiles reference/Homo_sapiens.GRCh38.dna.chromosome.22.fa \
    --sjdbGTFfile reference/Homo_sapiens.GRCh38.109.gtf \
    --genomeSAindexNbases 9
# Out:
# 	/content/STAR-2.7.10a/bin/Linux_x86_64_static/STAR --runThreadN 4 --runMode genomeGenerate --genomeDir star_index --genomeFastaFiles reference/Homo_sapiens.GRCh38.dna.chromosome.22.fa --sjdbGTFfile reference/Homo_sapiens.GRCh38.109.gtf --genomeSAindexNbases 9
# 	STAR version: 2.7.10a   compiled: 2022-01-14T18:50:00-05:00 :/home/dobin/data/STAR/STARcode/STAR.master/source
# Nov 11 05:16:36 ..... started STAR run
# Nov 11 05:16:36 ... starting to generate Genome files
# Nov 11 05:16:37 ..... processing annotations GTF
# Nov 11 05:16:44 ... starting to sort Suffix Array. This may take a long time...
# Nov 11 05:16:44 ... sorting Suffix Array chunks and saving them to disk...
# Nov 11 05:16:53 ... loading chunks from disk, packing SA...
# Nov 11 05:16:54 ... finished generating suffix array
# Nov 11 05:16:54 ... generating Suffix Array index
# Nov 11 05:16:54 ... completed Suffix Array index
# Nov 11 05:16:54 ..... inserting junctions into the genome indices
# Nov 11 05:16:58 ... writing Genome to disk ...
# Nov 11 05:17:00 ... writing Suffix Array to disk ...
# Nov 11 05:17:00 ... writing SAindex to disk
# Nov 11 05:17:00 ..... finished successfully

# %%
#  Step 4: Run STAR Alignment
# Create output directory and align reads to reference genome
# !mkdir -p star_output
# !/content/STAR-2.7.10a/bin/Linux_x86_64_static/STAR \
    --runThreadN 4 \
    --genomeDir star_index \
    --readFilesIn SRR11548957_1.fastq SRR11548957_2.fastq \
    --outFileNamePrefix star_output/SRR11548957_ \
    --outSAMtype BAM SortedByCoordinate \
    --quantMode GeneCounts
# Out:
# 	/content/STAR-2.7.10a/bin/Linux_x86_64_static/STAR --runThreadN 4 --genomeDir star_index --readFilesIn SRR11548957_1.fastq SRR11548957_2.fastq --outFileNamePrefix star_output/SRR11548957_ --outSAMtype BAM SortedByCoordinate --quantMode GeneCounts
# 	STAR version: 2.7.10a   compiled: 2022-01-14T18:50:00-05:00 :/home/dobin/data/STAR/STARcode/STAR.master/source
# Nov 11 05:17:18 ..... started STAR run
# Nov 11 05:17:18 ..... loading genome
# Nov 11 05:17:18 ..... started mapping
# Nov 11 05:39:57 ..... finished mapping
# Nov 11 05:39:58 ..... started sorting BAM
# Nov 11 05:39:58 ..... finished successfully

# %%
#  Step 5: Inspect Output Files
# List key output files
# !ls -lh star_output/SRR11548957_Aligned.sortedByCoord.out.bam
# !ls -lh star_output/SRR11548957_ReadsPerGene.out.tab
# !cat star_output/SRR11548957_Log.final.out
# Out:
# -rw-r--r-- 1 root root 19M Nov 11 05:39 star_output/SRR11548957_Aligned.sortedByCoord.out.bam
# -rw-r--r-- 1 root root 32K Nov 11 05:39 star_output/SRR11548957_ReadsPerGene.out.tab
#                                  Started job on |	Nov 11 05:17:18
#                              Started mapping on |	Nov 11 05:17:18
#                                     Finished on |	Nov 11 05:39:58
#        Mapping speed, Million of reads per hour |	4.74
#
#                           Number of input reads |	1792464
#                       Average input read length |	150
#                                     UNIQUE READS:
#                    Uniquely mapped reads number |	156947
#                         Uniquely mapped reads % |	8.76%
#                           Average mapped length |	141.22
#                        Number of splices: Total |	12073
#             Number of splices: Annotated (sjdb) |	6261
#                        Number of splices: GT/AG |	10520
#                        Number of splices: GC/AG |	209
#                        Number of splices: AT/AC |	7
#                Number of splices: Non-canonical |	1337
#                       Mismatch rate per base, % |	5.16%
#                          Deletion rate per base |	0.11%
#                         Deletion average length |	2.96
#                         Insertion rate per base |	0.17%
#                        Insertion average length |	2.05
#                              MULTI-MAPPING READS:
#         Number of reads mapped to multiple loci |	29782
#              % of reads mapped to multiple loci |	1.66%
#         Number of reads mapped to too many loci |	1463
#              % of reads mapped to too many loci |	0.08%
#                                   UNMAPPED READS:
#   Number of reads unmapped: too many mismatches |	0
#        % of reads unmapped: too many mismatches |	0.00%
#             Number of reads unmapped: too short |	1602192
#                  % of reads unmapped: too short |	89.38%
#                 Number of reads unmapped: other |	2080
#                      % of reads unmapped: other |	0.12%
#                                   CHIMERIC READS:
#                        Number of chimeric reads |	0
#                             % of chimeric reads |	0.00%

# %%
# Step 6: Download Output Files (Colab)
from google.colab import files
files.download('star_output/SRR11548957_Aligned.sortedByCoord.out.bam')
files.download('star_output/SRR11548957_ReadsPerGene.out.tab')
files.download('star_output/SRR11548957_Log.final.out')

# %% [markdown]
# # Task
# Generate a Plotly plot of the STAR alignment results from the log file "star_output/SRR11548957_Log.final.out".

# %% [markdown]
# ## Parse log file
#
# ### Subtask:
# Read the `star_output/SRR11548957_Log.final.out` file and extract the relevant mapping statistics (e.g., unique mapping percentage, multi-mapping percentage, unmapped percentages).

# %% [markdown]
# **Reasoning**:
# I need to read the log file and extract the relevant mapping statistics to prepare for plotting. I will use Python to open and parse the file, extracting the required percentages.

# %%
import pandas as pd

log_file_path = 'star_output/SRR11548957_Log.final.out'
mapping_stats = {}

with open(log_file_path, 'r') as f:
    for line in f:
        if 'Uniquely mapped reads %' in line:
            mapping_stats['Uniquely mapped reads %'] = float(line.split('|')[-1].strip().replace('%', ''))
        elif '% of reads mapped to multiple loci' in line:
            mapping_stats['% of reads mapped to multiple loci'] = float(line.split('|')[-1].strip().replace('%', ''))
        elif '% of reads mapped to too many loci' in line:
            mapping_stats['% of reads mapped to too many loci'] = float(line.split('|')[-1].strip().replace('%', ''))
        elif '% of reads unmapped: too many mismatches' in line:
            mapping_stats['% of reads unmapped: too many mismatches'] = float(line.split('|')[-1].strip().replace('%', ''))
        elif '% of reads unmapped: too short' in line:
            mapping_stats['% of reads unmapped: too short'] = float(line.split('|')[-1].strip().replace('%', ''))
        elif '% of reads unmapped: other' in line:
            mapping_stats['% of reads unmapped: other'] = float(line.split('|')[-1].strip().replace('%', ''))

print(mapping_stats)
# Out:
# {'Uniquely mapped reads %': 8.76, '% of reads mapped to multiple loci': 1.66, '% of reads mapped to too many loci': 0.08, '% of reads unmapped: too many mismatches': 0.0, '% of reads unmapped: too short': 89.38, '% of reads unmapped: other': 0.12}

# %% [markdown]
# ## Prepare data for plotting
#
# ### Subtask:
# Organize the extracted statistics into a format suitable for Plotly. A pandas DataFrame would be ideal.

# %% [markdown]
# **Reasoning**:
# Convert the mapping statistics dictionary into a pandas DataFrame with 'Category' and 'Percentage' columns as required.

# %%
mapping_df = pd.DataFrame(list(mapping_stats.items()), columns=['Category', 'Percentage'])
display(mapping_df)
# Out:
#                                    Category  Percentage
# 0                   Uniquely mapped reads %        8.76
# 1        % of reads mapped to multiple loci        1.66
# 2        % of reads mapped to too many loci        0.08
# 3  % of reads unmapped: too many mismatches        0.00
# 4            % of reads unmapped: too short       89.38
# 5                % of reads unmapped: other        0.12

# %% [markdown]
# ## Generate plotly plot
#
# ### Subtask:
# Create a bar chart or a pie chart using Plotly to visualize the different mapping categories (uniquely mapped, multi-mapped, unmapped).

# %% [markdown]
# **Reasoning**:
# Generate a pie chart using Plotly to visualize the mapping statistics stored in the `mapping_df` DataFrame.

# %%
import plotly.express as px

fig = px.pie(mapping_df, values='Percentage', names='Category', title='STAR Alignment Mapping Statistics')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="69b9930d-8c55-4bcc-8c35-554b9a594fa8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69b9930d-8c55-4bcc-8c35-554b9a594fa8")) {                    Plotly.newPlot(                        "69b9930d-8c55-4bcc-8c35-554b9a594fa8",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Category=%{label}\u003cbr\u003ePercentage=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Uniquely mapped reads %","% of reads mapped to multiple loci","% of reads mapped to too many loci","% of reads unmapped: too many mismatches","% of reads unmapped: too short","% of reads unmapped: other"],"legendgroup":"","name":"","showlegend":true,"values":[8.76,1.66,0.08,0.0,89.38,0.12],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type" ...

# %% [markdown]
# ## Display plot
#
# ### Subtask:
# Display the generated Plotly plot in the notebook.

# %% [markdown]
# **Reasoning**:
# Display the generated Plotly plot in the notebook.

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="33abe2dc-514e-4d88-a9b8-fac187ec6b5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33abe2dc-514e-4d88-a9b8-fac187ec6b5d")) {                    Plotly.newPlot(                        "33abe2dc-514e-4d88-a9b8-fac187ec6b5d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Category=%{label}\u003cbr\u003ePercentage=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Uniquely mapped reads %","% of reads mapped to multiple loci","% of reads mapped to too many loci","% of reads unmapped: too many mismatches","% of reads unmapped: too short","% of reads unmapped: other"],"legendgroup":"","name":"","showlegend":true,"values":[8.76,1.66,0.08,0.0,89.38,0.12],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type" ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The STAR alignment log file was successfully parsed to extract mapping statistics.
# *   The extracted statistics were organized into a pandas DataFrame, including categories like "Uniquely mapped reads %", "% of reads mapped to multiple loci", and various unmapped categories.
# *   A Plotly pie chart was generated to visualize the distribution of reads across these mapping categories.
#
# ### Insights or Next Steps
#
# *   The pie chart provides a clear visual overview of the STAR alignment efficiency, highlighting the proportion of reads in different mapping categories.
# *   Analyze the percentages of unmapped reads to identify potential issues with read quality, reference genome, or alignment parameters.

# %% [markdown]
# Here is a detailed interpretation of the key metrics from the `star_output/SRR11548957_Log.final.out` file:
#
# *   **Started job on**: Indicates the date and time when the STAR alignment job began.
# *   **Started mapping on**: Indicates the date and time when the read mapping process started.
# *   **Finished on**: Indicates the date and time when the entire STAR alignment job finished.
# *   **Mapping speed, Million of reads per hour**: This metric shows the processing speed of STAR, indicating how many million reads were aligned per hour. A higher number indicates faster processing.
# *   **Number of input reads**: The total number of reads provided as input to STAR.
# *   **Average input read length**: The average length of the input reads.
# *   **UNIQUE READS:** Section detailing statistics for reads that mapped to only one location in the reference genome.
# *   **Uniquely mapped reads number**: The total count of reads that mapped uniquely to the genome.
# *   **Uniquely mapped reads %**: The percentage of total input reads that mapped uniquely. This is a crucial metric for assessing the quality of the alignment. A higher percentage is generally better.
# *   **Average mapped length**: The average length of the uniquely mapped reads.
# *   **Number of splices: Total**: The total number of splice junctions detected by STAR.
# *   **Number of splices: Annotated (sjdb)**: The number of detected splice junctions that match known splice junctions provided in the GTF annotation file.
# *   **Number of splices: GT/AG**: The number of splice junctions with the canonical GT/AG intron motif. This is the most common type of splice junction.
# *   **Number of splices: GC/AG**: The number of splice junctions with the GC/AG intron motif, another common type.
# *   **Number of splices: AT/AC**: The number of splice junctions with the less common AT/AC intron motif.
# *   **Number of splices: Non-canonical**: The number of splice junctions that do not match any of the canonical or common non-canonical motifs. A high number here might indicate issues with the data or alignment.
# *   **Mismatch rate per base, %**: The percentage of bases that are mismatched between the reads and the reference genome. A low mismatch rate is desirable.
# *   **Deletion rate per base**: The rate of deletions per base in the aligned reads compared to the reference.
# *   **Deletion average length**: The average length of deletions.
# *   **Insertion rate per base**: The rate of insertions per base in the aligned reads compared to the reference.
# *   **Insertion average length**: The average length of insertions.
# *   **MULTI-MAPPING READS:** Section detailing statistics for reads that mapped to more than one location in the reference genome.
# *   **Number of reads mapped to multiple loci**: The total count of reads that mapped to multiple locations.
# *   **% of reads mapped to multiple loci**: The percentage of total input reads that mapped to multiple locations.
# *   **Number of reads mapped to too many loci**: The count of reads that mapped to more locations than the maximum allowed by STAR's parameters.
# *   **% of reads mapped to too many loci**: The percentage of total input reads that mapped to too many locations.
# *   **UNMAPPED READS:** Section detailing statistics for reads that did not map to the reference genome.
# *   **Number of reads unmapped: too many mismatches**: The count of reads that did not map due to exceeding the allowed number of mismatches.
# *   **% of reads unmapped: too many mismatches**: The percentage of total input reads that did not map due to too many mismatches.
# *   **Number of reads unmapped: too short**: The count of reads that did not map because they were too short after trimming or soft clipping.
# *   **% of reads unmapped: too short**: The percentage of total input reads that did not map because they were too short.
# *   **Number of reads unmapped: other**: The count of reads that did not map for reasons other than too many mismatches or being too short.
# *   **% of reads unmapped: other**: The percentage of total input reads that did not map for other reasons.
# *   **CHIMERIC READS:** Section detailing statistics for chimeric reads (reads that map to two different locations).
# *   **Number of chimeric reads**: The total count of chimeric reads detected.
# *   **% of chimeric reads**: The percentage of total input reads that were identified as chimeric.

# %% [markdown]
# Here is a summary of the key findings from the STAR alignment of SRR11548957:
#
# *   **Mapping Speed:** The alignment processed reads at a rate of 4.74 million reads per hour.
# *   **Input Reads:** A total of 1,792,464 reads were input for alignment, with an average length of 150 bases.
# *   **Uniquely Mapped Reads:** Only 8.76% of the reads (156,947) uniquely mapped to the reference genome (chromosome 22). This is a relatively low unique mapping rate, suggesting either the reads are from a different genome/chromosome, the reference genome is incomplete, or there are issues with the read quality or adapter trimming.
# *   **Multi-mapping Reads:** 1.66% of reads (29,782) mapped to multiple locations, and a very small percentage (0.08%) mapped to too many loci.
# *   **Unmapped Reads:** A large majority of reads (89.38%) were unmapped because they were too short. This is a significant percentage and might indicate issues with the quality of the input reads or the chosen alignment parameters. A small percentage (0.12%) were unmapped for other reasons.
# *   **Splice Junctions:** A total of 12,073 splice junctions were detected, with a good proportion (6,261) being annotated in the provided GTF file. The majority of detected junctions have canonical GT/AG (10,520) and GC/AG (209) motifs, with a smaller number of non-canonical junctions (1337).
# *   **Mismatch, Deletion, and Insertion Rates:** The mismatch rate per base was 5.16%, which is quite high. The deletion and insertion rates were lower, at 0.11% and 0.17% respectively.
#
# **Overall Assessment:** The alignment had a very low unique mapping rate and a high percentage of reads unmapped due to being too short, as well as a high mismatch rate. This suggests potential issues with the input data quality or that the chosen reference (chromosome 22) may not be the most appropriate for these reads. Further investigation into the read quality and the expected origin of the sequencing data would be recommended.

# %% [markdown]
# **Conclusion of the RNA-Seq Alignment Workflow:**
#
# This notebook demonstrates a basic RNA-Seq alignment workflow using STAR, focusing on a subset of data (SRR11548957) and a specific reference genome (human chromosome 22). The steps performed were:
#
# 1.  **Environment Setup:** Installed necessary tools and libraries including `sra-toolkit` for data download and `STAR` for alignment.
# 2.  **Data Download:** Downloaded paired-end FASTQ files for the accession SRR11548957 from the SRA database.
# 3.  **Reference Preparation:** Downloaded and uncompressed the reference genome sequence (chromosome 22) and the corresponding GTF annotation file from Ensembl.
# 4.  **Genome Indexing:** Generated a STAR genome index using the downloaded reference genome and GTF file. This is a crucial step for efficient alignment.
# 5.  **Read Alignment:** Aligned the downloaded FASTQ reads to the generated STAR index, producing a sorted BAM file and gene counts.
# 6.  **Output Inspection and Download:** Inspected key output files (`Aligned.sortedByCoord.out.bam`, `ReadsPerGene.out.tab`, and `Log.final.out`) and provided code to download them.
#
# **Summary of Findings:**
#
# Based on the `Log.final.out` analysis, while the alignment successfully ran, the unique mapping rate was low (8.76%), and a high percentage of reads (89.38%) were unmapped due to being too short. The mismatch rate was also relatively high (5.16%). This suggests that the reads might not be primarily from chromosome 22 or that there are quality issues with the sequencing data.
#
# **Next Steps:**
#
# For a complete RNA-Seq analysis, the next steps would typically involve:
#
# *   More in-depth quality control of the raw reads (e.g., using FastQC and MultiQC before alignment).
# *   Considering aligning to the full human genome for a more comprehensive analysis.
# *   Performing differential gene expression analysis using the gene counts obtained from STAR and appropriate statistical software (e.g., DESeq2, edgeR).
# *   Further downstream analysis and visualization of the results.
